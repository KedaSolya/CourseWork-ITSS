# %%
import pickle
import pandas as pd
import numpy as np
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

import warnings
warnings.simplefilter('ignore')

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
# custom files
import model_best_hyperparameters

# %%
# read train data
ds = pd.read_csv("../data/new_data.csv")
print('new data size', ds.shape)
# Out:
# new data size (3065, 14)

# %%
ds.head()
# Out:
#    Gender EthnicGroup          ParentEduc     LunchType   TestPrep
# 0  female     group B    some high school      standard  completed  \
# 1    male     group E                 NaN      standard  completed
# 2    male     group C  associate's degree      standard        NaN
# 3  female     group E    some high school  free/reduced       none
# 4    male     group B         high school  free/reduced  completed
#
#   PracticeSport IsFirstChild  NrSiblings WklyStudyHours  MathScore
# 0     regularly           no         3.0            < 5         70  \
# 1     sometimes          yes         2.0         5 - 10         90
# 2     sometimes          yes         4.0            < 5         81
# 3     regularly          yes         0.0         5 - 10         55
# 4         never           no         2.0         5 - 10         49
#
#    ReadingScore  WritingScore  AverageScore  Passed
# 0            87            87     81.333333       1
# 1            83            84     85.666667       1
# 2            89            81     83.666667       1
# 3            57            55     55.666667       1
# 4            50            53     50.666667       1

# %%
mean_impute_columns = [
 'MathScore',
 'ReadingScore',
 'WritingScore',
 'AverageScore']

mode_impute_columns = [
 'Gender',
 'EthnicGroup',
 'ParentEduc',
 'LunchType',
 'TestPrep',
 'PracticeSport',
 'IsFirstChild',
 'NrSiblings',
 'WklyStudyHours',
 'Passed']

# %%
def impute_na(df, variable, value):
    return df[variable].fillna(value)

# %%
# Let's create a dict and impute mean values
mean_impute_values = dict()
for column in mean_impute_columns:
    mean_impute_values[column] = ds[column].mean()
    ds[column] = impute_na(ds, column, mean_impute_values[column])

# %%
# Let's create a dict and impute mode values
mode_impute_values = dict()
for column in mode_impute_columns:
    mode_impute_values[column] = ds[column].mode()[0]
    ds[column] = impute_na(ds, column, mode_impute_values[column])

# %%
print("Any missing sample in training set:",ds.isnull().values.any())
# Out:
# Any missing sample in training set: False

# %%
ds.head()
# Out:
#    Gender EthnicGroup          ParentEduc     LunchType   TestPrep
# 0  female     group B    some high school      standard  completed  \
# 1    male     group E        some college      standard  completed
# 2    male     group C  associate's degree      standard       none
# 3  female     group E    some high school  free/reduced       none
# 4    male     group B         high school  free/reduced  completed
#
#   PracticeSport IsFirstChild  NrSiblings WklyStudyHours  MathScore
# 0     regularly           no         3.0            < 5         70  \
# 1     sometimes          yes         2.0         5 - 10         90
# 2     sometimes          yes         4.0            < 5         81
# 3     regularly          yes         0.0         5 - 10         55
# 4         never           no         2.0         5 - 10         49
#
#    ReadingScore  WritingScore  AverageScore  Passed
# 0            87            87     81.333333       1
# 1            83            84     85.666667       1
# 2            89            81     83.666667       1
# 3            57            55     55.666667       1
# 4            50            53     50.666667       1

# %% [markdown]
# # feature engineering

# %%
cat_columns = [
 'Gender',
 'EthnicGroup',
 'ParentEduc',
 'LunchType',
 'TestPrep',
 'PracticeSport',
 'IsFirstChild',
 'NrSiblings',
 'WklyStudyHours',
 'Passed']

# %%
# Categorical encoding
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for column in cat_columns:
    ds[column]=le.fit_transform(ds[column])

# %%
ds.head()
# Out:
#    Gender  EthnicGroup  ParentEduc  LunchType  TestPrep  PracticeSport
# 0       0            1           5          1         0              1  \
# 1       1            4           4          1         0              2
# 2       1            2           0          1         1              2
# 3       0            4           5          0         1              1
# 4       1            1           2          0         0              0
#
#    IsFirstChild  NrSiblings  WklyStudyHours  MathScore  ReadingScore
# 0             0           3               1         70            87  \
# 1             1           2               0         90            83
# 2             1           4               1         81            89
# 3             1           0               0         55            57
# 4             0           2               0         49            50
#
#    WritingScore  AverageScore  Passed
# 0            87     81.333333       1
# 1            84     85.666667       1
# 2            81     83.666667       1
# 3            55     55.666667       1
# 4            53     50.666667       1

# %%
X = ds.drop(['Passed'], axis=1)
y = ds['Passed']

# %%
# load the model and predict
knn = pickle.load(open('finalized_model.sav', 'rb'))

# %%
y_pred = knn.predict(X.values)

# %%
predictions = knn.predict(X.values)
original_labels = le.inverse_transform(predictions)
original_charges_cat = le.inverse_transform(ds['Passed'])
ds['Passed_pred'] = original_labels
ds['Passed'] = original_charges_cat
ds.to_csv('prediction_results.csv', index=False)

# %%
pr = pd.read_csv("prediction_results.csv")

# %%
pr.sample(20)
# Out:
#       Gender  EthnicGroup  ParentEduc  LunchType  TestPrep  PracticeSport
# 370        1            0           2          1         1              2  \
# 109        0            2           4          1         1              1
# 2387       1            3           0          0         0              2
# 130        0            1           0          1         1              0
# 163        0            2           4          0         1              1
# 2517       1            1           1          1         1              2
# 1700       1            2           0          0         1              1
# 2971       0            2           2          1         0              2
# 2376       1            2           1          1         1              1
# 1065       1            2           2          0         1              1
# 690        1            1           3          0         1              1
# 340        0            2           0          0         1              1
# 2332       0            0           5          0         1              1
# 1612       0            0           4          1         1              1
# 2136       1            2           0          1         1              2
# 1281       1            3           5          1         0              2
# 2635       0            3           4          1         1              2
# 516        0            2           5          1         1              1
# 1524       0            3           5          1         1              2
# 2625       0            1           0          1         1              2
#
#       IsFirstChild  NrSiblings  WklyStudyHours  MathScore  ReadingScore
# 370              1           2               0         59            52  \
# 109              1           2               0         87            90
# 2387             1           0               0         83            85
# 130              1           0               2         53            58
# 163              1           1               0         55            68
# 2517             1           2               2         93            89
# 1700             1           1               0         43            45
# 2971             1           4               0         47            61
# 2376             1           2               0         48            52
# 1065             0           3               0         38            39
# 690              1           1               0         50            45
# 340              0           7               0         56            74
# 2332             1           1               2         42            53
# 1612             0           7               1         45            55
# 2136             0           3               1         45            36
# 1281             0           4               0         62            66
# 2635             0           2               0         68            79
# 516              0           1               1         61            67
# 1524             1           0               0         51            62
# 2625             0           1               0         66            74
#
#       WritingScore  AverageScore  Passed  Passed_pred
# 370             46     52.333333       1            1
# 109             90     89.000000       1            1
# 2387            84     84.000000       1            1
# 130             51     54.000000       1            1
# 163             60     61.000000       1            1
# 2517            84     88.666667       1            1
# 1700            43     43.666667       0            0
# 2971            73     60.333333       1            1
# 2376            51     50.333333       1            1
# 1065            41     39.333333       0            0
# 690             45     46.666667       0            0
# 340             65     65.000000       1            1
# 2332            48     47.666667       0            0
# 1612            51     50.333333       1            1
# 2136            34     38.333333       0            0
# 1281            68     65.333333       1            1
# 2635            81     76.000000       1            1
# 516             68     65.333333       1            1
# 1524            67     60.000000       1            1
# 2625            69     69.666667       1            1
